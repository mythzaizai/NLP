# %%
import jieba
import jieba.analyse
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
def main():
    print("test")





if __name__ == '__main__':
    main()
# Out:
# 權重排名(前100)
#    word    TF-IDF
# 0    什麼  0.194066
# 1    八卦  0.162799
# 2    台灣  0.117160
# 3    怎麼  0.109951
# 4    肥宅  0.060883
# ..  ...       ...
# 95   韓國  0.007610
# 96   新聞  0.007610
# 97   電影  0.007410
# 98   電腦  0.007410
# 99  金城武  0.007219
#
# [100 rows x 2 columns]
# 權重圖(fig1):
# 出現頻率排名(前100)
#    word  Frequncy
# 0    八卦      1115
# 1    什麼       961
# 2    怎麼       555
# 3    台灣       537
# 4   是不是       444
# ..  ...       ...
# 95   高雄        46
# 96   男生        46
# 97   好像        45
# 98   代表        45
# 99   最好        45
#
# [100 rows x 2 columns]
# 頻率圖(fig2):
